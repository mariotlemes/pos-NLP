# %%
import pandas as pd
import seaborn as sns

url = 'https://raw.githubusercontent.com/vodena/GRIDouble/refs/heads/main/data/Data_Cacak.csv'
energia_solar = pd.read_csv(url)
energia_solar.head()
# Out:
#            Datetime  AirTemperature  CloudOpacity  DHI  DNI  EBH  GHI  \
# 0  11/22/2022 14:00             8.7            59  117  0.0    0  117
# 1  11/22/2022 15:00             8.9            62   62  0.0    0   62
# 2  11/22/2022 16:00             9.2            57   15  7.0    1   16
# 3  11/22/2022 17:00             8.9            81    0  0.0    0    0
# 4  11/22/2022 18:00             8.9            91    0  0.0    0    0
#
#    Production - Location 1  Production - Location 2  Production - Location 3
# 0                11.705333                12.694917                16.355417
# 1                 1.309583                 8.262333                 1.812333
# 2                 0.000000                 0.930667                 0.000000
# 3                 0.000000                 0.000000                 0.000000
# 4                 0.000000                 0.000000                 0.000000

# %%
# quantidade de instâncias
print(f"Instâncias: {energia_solar.shape[0]}")
print(f"Atributos: {energia_solar.shape[1]}")
# Out:
# Instâncias: 8274
# Atributos: 10

# %%
energia_solar[energia_solar.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Datetime, AirTemperature, CloudOpacity, DHI, DNI, EBH, GHI, Production - Location 1, Production - Location 2, Production - Location 3]
# Index: []

# %%
energia_solar.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8274 entries, 0 to 8273
# Data columns (total 10 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Datetime                 8274 non-null   object
#  1   AirTemperature           8274 non-null   float64
#  2   CloudOpacity             8274 non-null   int64
#  3   DHI                      8274 non-null   int64
#  4   DNI                      8274 non-null   float64
#  5   EBH                      8274 non-null   int64
#  6   GHI                      8274 non-null   int64
#  7   Production - Location 1  8274 non-null   float64
#  8   Production - Location 2  8274 non-null   float64
#  9   Production - Location 3  8274 non-null   float64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 646.5+ KB

# %%
# plt.suptitle("Gráfico de calor das variáveis numéricas")
dados_numericos = energia_solar.select_dtypes(include=['int', 'float', 'bool'])
ax = sns.heatmap(dados_numericos.corr(), annot=True, cmap="Greens")
